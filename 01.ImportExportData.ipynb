# %% [markdown]
# # <center> IMPORTANDO Y EXPORTANDO DATA </center>
# ## 1. Importando datos
# ### 1.1 Importando desde una interfaz
# Desde un archivo (Plano: txt, csv ó con unformato avanzado: RData, sas7...., sav,....)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
#Localmente (Esta en Mi PC o una ruta compartida)
df1=pd.read_csv("/content/sample_data/bikes.csv")
df1.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df1.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df1.shape
# Out:
# (10886, 12)

# %%
df1.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %% [markdown]
# ### 1.2 Importando desde una fuente de datos
# Entidades, Esquemas, Tablas ( from SGDB, Hadoop, Storage: s3, Adls, GDS)
# Host, DBname, usuario, password, Query

# %%
# https://relational.fit.cvut.cz/dataset/Financial  (Base de datos Mysql que expone libremente su data)
#usuario: guest, password: relational, host:relational.fit.cvut.cz, base dedatos: financial

# librerias requeridas para Mysql
from sqlalchemy import create_engine
import pymysql
#Estableciendo la conexion ('mysql+pymysql://mysql_user:mysql_password@mysql_host/mysql_db')
db_connection_str = 'mysql+pymysql://guest:relational@relational.fit.cvut.cz/financial'
db_connection = create_engine(db_connection_str)
#Importando la data
df_loan = pd.read_sql('SELECT * FROM loan', con=db_connection)
df_loan.head()

# %%
df_account = pd.read_sql('SELECT * FROM account', con=db_connection)
df_account.head()

# %%
df_account.info()

# %% [markdown]
# ## 2. Exportando datos
# Cuando cerremos el notebook, todas las variables (dataframe) desaparece, por lo tanto es una muy buena practica respaldar la data extraida.

# %%
df_loan.to_csv("df_loan.csv", index=False)
df_account.to_csv("df_account.csv", index=False)
#df_account.to_parquet('df_account.parquet.gzip',compression='gzip')

# %%
df1.to_csv("df1.csv", index=False)
